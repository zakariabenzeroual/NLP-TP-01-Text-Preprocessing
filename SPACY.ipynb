# %% [markdown]
# # NLP TP 01 Text Preprocessing
# ### spaCy ARABIC AND ENGLISH

# %%
import spacy
from spacy.lang.ar import *

# %% [markdown]
# #### 1- Loading data :

# %%
text_EN = "Perhaps one of the most significant advances made by Arabic mathematics began at this time with the work of al-Khwarizmi, namely the beginnings of algebra. It is important to understand just how significant this new idea was. It was a revolutionary move away from the Greek concept of mathematics which was essentially geometry. Algebra was a unifying theory which allowedrational numbers,irrational numbers, geometrical magnitudes, etc., to all be treated as \"algebraic objects\". It gave mathematics a whole new development path so much broader in concept to that which had existed before, and provided a vehicle for future development of the subject. Another important aspect of the introduction of algebraic ideas was that it allowed mathematics to be applied to itselfin a way which had not happened before."
print(text_EN)

text_AR = "ربما كانت أحد أهم التطورات التي قامت بها الرياضيات العربية التي بدأت في هذا الوقت بعمل الخوارزمي وهي بدايات الجبر, ومن المهم فهم كيف كانت هذه الفكرة الجديدة مهمة, فقد كانت خطوة نورية بعيدا عن المفهوم اليوناني للرياضيات التي هي في جوهرها هندسة, الجبر کان نظرية موحدة تتيح الأعداد الكسرية والأعداد اللا كسرية, والمقادير الهندسية وغيرها, أن تتعامل على أنها أجسام جبرية, وأعطت الرياضيات ككل مسارا جديدا للتطور بمفهوم أوسع بكثير من الذي كان موجودا من قبل, وقم وسيلة للتنمية في هذا الموضوع مستقبلا. وجانب آخر مهم لإدخال أفكار الجبر وهو أنه سمح بتطبيق الرياضيات على نفسها بطريقة لم تحدث من قبل"
print(text_AR)
# Out:
# Perhaps one of the most significant advances made by Arabic mathematics began at this time with the work of al-Khwarizmi, namely the beginnings of algebra. It is important to understand just how significant this new idea was. It was a revolutionary move away from the Greek concept of mathematics which was essentially geometry. Algebra was a unifying theory which allowedrational numbers,irrational numbers, geometrical magnitudes, etc., to all be treated as "algebraic objects". It gave mathematics a whole new development path so much broader in concept to that which had existed before, and provided a vehicle for future development of the subject. Another important aspect of the introduction of algebraic ideas was that it allowed mathematics to be applied to itselfin a way which had not happened before.
# ربما كانت أحد أهم التطورات التي قامت بها الرياضيات العربية التي بدأت في هذا الوقت بعمل الخوارزمي وهي بدايات الجبر, ومن المهم فهم كيف كانت هذه الفكرة الجديدة مهمة, فقد كانت خطوة نورية بعيدا عن المفهوم اليوناني للرياضيات التي هي في جوهرها هندسة, الجبر کان نظرية موحدة تتيح الأعداد الكسرية والأعداد اللا كسرية, والمقادير الهندسية وغيرها, أن تتعامل على أنها أجسام جبرية, وأعطت الرياضيات ككل مسارا جديدا للتطور بمفهوم أوسع بكثير من الذي كان موجودا من قبل, وقم وسيلة للتنمية في هذا الموضوع مستقبلا. وجانب آخر مهم لإدخال أفكار الجبر وهو أنه سمح بتطبيق الرياضيات على نفسها بطريقة لم تحدث من قبل

# %% [markdown]
# #### 2- Convert text to lowercase, Remove punctuation, Tokenization :

# %%
import re

# Convert text to lowercase :

text_EN = text_EN.lower()
print(text_EN)

# Remove punctuation :

text_EN = re.sub(r'[^\w\s]','',text_EN)
print(text_EN)

text_AR = re.sub(r'[^\w\s]','',text_AR)
print(text_AR)

# Tokenization :

nlp = spacy.load("en_core_web_sm")

# In this example, some of the commonly required attributes are accessed:
#   is_alpha : detects if the token consists of alphabetic characters or not.
#   is_punct : detects if the token is a punctuation symbol or not.
#   is_space : detects if the token is a space or not.
#   shape_   : prints out the shape of the word.
#   is_stop  : detects if the token is a stop word or not.

# Tokenization AR :

token_AR = Arabic()
token_AR = nlp(text_AR)
for token in token_AR:
    print (token, token.idx,token.is_alpha, token.is_punct, token.is_space,token.shape_, token.is_stop)

# Tokenization EN :

token_EN = nlp(text_EN)
for token in token_EN:
    print (token, token.idx,token.is_alpha, token.is_punct, token.is_space,token.shape_, token.is_stop)
# Out:
# perhaps one of the most significant advances made by arabic mathematics began at this time with the work of alkhwarizmi namely the beginnings of algebra it is important to understand just how significant this new idea was it was a revolutionary move away from the greek concept of mathematics which was essentially geometry algebra was a unifying theory which allowedrational numbersirrational numbers geometrical magnitudes etc to all be treated as algebraic objects it gave mathematics a whole new development path so much broader in concept to that which had existed before and provided a vehicle for future development of the subject another important aspect of the introduction of algebraic ideas was that it allowed mathematics to be applied to itselfin a way which had not happened before
# perhaps one of the most significant advances made by arabic mathematics began at this time with the work of alkhwarizmi namely the beginnings of algebra it is important to understand just how significant this new idea was it was a revolutionary move away from the greek concept of mathematics which was essentially geometry algebra was a unifying theory which allowedrational numbersirrational numbers geometrical magnitudes etc to all be treated as algebraic objects it gave mathematics a whole new development path so much broader in concept to that which had existed before and provided a vehicle for future development of the subject another important aspect of the introduction of algebraic ideas was that it allowed mathematics to be applied to itselfin a way which had not happened before
# ربما كانت أحد أهم التطورات التي قامت بها الرياضيات العربية التي بدأت في هذا الوقت بعمل الخوارزمي وهي بدايات الجبر ومن المهم فهم كيف كانت هذه الفكرة الجديدة مهمة فقد كانت خطوة نورية بعيدا عن المفهوم اليوناني للرياضيات التي هي في جوهرها هندسة الجبر کان نظرية موحدة تتيح الأعداد الكسرية والأعداد اللا كسرية والمقادير الهندسية وغيرها أن تتعامل على أنها أجسام جبرية وأعطت الرياضيات ككل مسارا جديدا للتطور بمفهوم أوسع بكثير من الذي كان موجودا من قبل وقم وسيلة للتنمية في هذا الموضوع مستقبلا وجانب آخر مهم لإدخال أفكار الجبر وهو أنه سمح بتطبيق الرياضيات على نفسها بطريقة لم تحدث من قبل
# ربما 0 True False False xxxx False
# كانت 5 True False False xxxx False
# أحد 10 True False False xxx False
# أهم 14 True False False xxx False
# التطورات 18 True False False xxxx False
# التي 27 True False False xxxx False
# قامت 32 True False False xxxx False
# بها 37 True False False xxx False
# الرياضيات 41 True False False xxxx False
# العربية 51 True False False xxxx False
# التي 59 True False False xxxx False
# بدأت 64 True False False xxxx False
# في 69 True False False xx False
# هذا 72 True False False xxx False
# الوقت 76 True False False xxxx False
# بعمل 82 True False False xxxx False
# الخوارزمي 87 True False False xxxx False
# وهي 97 True False False xxx False
# بدايات 101 True False False xxxx False
# الجبر 108 True False False xxxx False
# ومن 114 True False False xxx False
# المهم 118 True False False xxxx False
# فهم 124 True False False xxx False
# كيف 128 True False False xxx False
# كانت 132 True False False xxxx False
# هذه 137 True False False xxx False
# الفكرة 141 True False False xxxx False
# الجديدة 148 True False False xxxx False
# مهمة 156 True False False xxxx False
# فقد 161 True False False xxx False
# كانت 165 True False False xxxx False
# خطوة 170 True False False xxxx False
# نورية 175 True False False xxxx False
# بعيدا 181 True False False xxxx False
# عن 187 True False False xx False
# المفهوم 190 True False False xxxx False
# اليوناني 198 True False False xxxx False
# للرياضيات 207 True False False xxxx False
# التي 217 True False False xxxx False
# هي 222 True False False xx False
# في 225 True False False xx False
# جوهرها 228 True False False xxxx False
# هندسة 235 True False False xxxx False
# الجبر 241 True False False xxxx False
# کان 247 True False False xxx False
# نظرية 251 True False False xxxx False
# موحدة 257 True False False xxxx False
# تتيح 263 True False False xxxx False
# الأعداد 268 True False False xxxx False
# الكسرية 276 True False False xxxx False
# والأعداد 284 True False False xxxx False
# اللا 293 True False False xxxx False
# كسرية 298 True False False xxxx False
# والمقادير 304 True False False xxxx False
# الهندسية 314 True False False xxxx False
# وغيرها 323 True False False xxxx False
# أن 330 True False False xx False
# تتعامل 333 True False False xxxx False
# على 340 True False False xxx False
# أنها 344 True False False xxxx False
# أجسام 349 True False False xxxx False
# جبرية 355 True False False xxxx False
# وأعطت 361 True False False xxxx False
# الرياضيات 367 True False False xxxx False
# ككل 377 True False False xxx False
# مسارا 381 True False False xxxx False
# جديدا 387 True False False xxxx False
# للتطور 393 True False False xxxx False
# بمفهوم 400 True False False xxxx False
# أوسع 407 True False False xxxx False
# بكثير 412 True False False xxxx False
# من 418 True False False xx False
# الذي 421 True False False xxxx False
# كان 426 True False False xxx False
# موجودا 430 True False False xxxx False
# من 437 True False False xx False
# قبل 440 True False False xxx False
# وقم 444 True False False xxx False
# وسيلة 448 True False False xxxx False
# للتنمية 454 True False False xxxx False
# في 462 True False False xx False
# هذا 465 True False False xxx False
# الموضوع 469 True False False xxxx False
# مستقبلا 477 True False False xxxx False
# وجانب 485 True False False xxxx False
# آخر 491 True False False xxx False
# مهم 495 True False False xxx False
# لإدخال 499 True False False xxxx False
# أفكار 506 True False False xxxx False
# الجبر 512 True False False xxxx False
# وهو 518 True False False xxx False
# أنه 522 True False False xxx False
# سمح 526 True False False xxx False
# بتطبيق 530 True False False xxxx False
# الرياضيات 537 True False False xxxx False
# على 547 True False False xxx False
# نفسها 551 True False False xxxx False
# بطريقة 557 True False False xxxx False
# لم 564 True False False xx False
# تحدث 567 True False False xxxx False
# من 572 True False False xx False
# قبل 575 True False False xxx False
# perhaps 0 True False False xxxx True
# one 8 True False False xxx True
# of 12 True False False xx True
# the 15 True False False xxx True
# most 19 True False False xxxx True
# significant 24 True False False xxxx False
# advances 36 True False False xxxx False
# made 45 True False False xxxx True
# by 50 True False False xx True
# arabic 53 True False False xxxx False
# mathematics 60 True False False xxxx False
# began 72 True False False xxxx False
# at 78 True False False xx True
# this 81 True False False xxxx True
# time 86 True False False xxxx False
# with 91 True False False xxxx True
# the 96 True False False xxx True
# work 100 True False False xxxx False
# of 105 True False False xx True
# alkhwarizmi 108 True False False xxxx False
# namely 120 True False False xxxx True
# the 127 True False False xxx True
# beginnings 131 True False False xxxx False
# of 142 True False False xx True
# algebra 145 True False False xxxx False
# it 153 True False False xx True
# is 156 True False False xx True
# important 159 True False False xxxx False
# to 169 True False False xx True
# understand 172 True False False xxxx False
# just 183 True False False xxxx True
# how 188 True False False xxx True
# significant 192 True False False xxxx False
# this 204 True False False xxxx True
# new 209 True False False xxx False
# idea 213 True False False xxxx False
# was 218 True False False xxx True
# it 222 True False False xx True
# was 225 True False False xxx True
# a 229 True False False x True
# revolutionary 231 True False False xxxx False
# move 245 True False False xxxx True
# away 250 True False False xxxx False
# from 255 True False False xxxx True
# the 260 True False False xxx True
# greek 264 True False False xxxx False
# concept 270 True False False xxxx False
# of 278 True False False xx True
# mathematics 281 True False False xxxx False
# which 293 True False False xxxx True
# was 299 True False False xxx True
# essentially 303 True False False xxxx False
# geometry 315 True False False xxxx False
# algebra 324 True False False xxxx False
# was 332 True False False xxx True
# a 336 True False False x True
# unifying 338 True False False xxxx False
# theory 347 True False False xxxx False
# which 354 True False False xxxx True
# allowedrational 360 True False False xxxx False
# numbersirrational 376 True False False xxxx False
# numbers 394 True False False xxxx False
# geometrical 402 True False False xxxx False
# magnitudes 414 True False False xxxx False
# etc 425 True False False xxx False
# to 429 True False False xx True
# all 432 True False False xxx True
# be 436 True False False xx True
# treated 439 True False False xxxx False
# as 447 True False False xx True
# algebraic 450 True False False xxxx False
# objects 460 True False False xxxx False
# it 468 True False False xx True
# gave 471 True False False xxxx False
# mathematics 476 True False False xxxx False
# a 488 True False False x True
# whole 490 True False False xxxx True
# new 496 True False False xxx False
# development 500 True False False xxxx False
# path 512 True False False xxxx False
# so 517 True False False xx True
# much 520 True False False xxxx True
# broader 525 True False False xxxx False
# in 533 True False False xx True
# concept 536 True False False xxxx False
# to 544 True False False xx True
# that 547 True False False xxxx True
# which 552 True False False xxxx True
# had 558 True False False xxx True
# existed 562 True False False xxxx False
# before 570 True False False xxxx True
# and 577 True False False xxx True
# provided 581 True False False xxxx False
# a 590 True False False x True
# vehicle 592 True False False xxxx False
# for 600 True False False xxx True
# future 604 True False False xxxx False
# development 611 True False False xxxx False
# of 623 True False False xx True
# the 626 True False False xxx True
# subject 630 True False False xxxx False
# another 638 True False False xxxx True
# important 646 True False False xxxx False
# aspect 656 True False False xxxx False
# of 663 True False False xx True
# the 666 True False False xxx True
# introduction 670 True False False xxxx False
# of 683 True False False xx True
# algebraic 686 True False False xxxx False
# ideas 696 True False False xxxx False
# was 702 True False False xxx True
# that 706 True False False xxxx True
# it 711 True False False xx True
# allowed 714 True False False xxxx False
# mathematics 722 True False False xxxx False
# to 734 True False False xx True
# be 737 True False False xx True
# applied 740 True False False xxxx False
# to 748 True False False xx True
# itselfin 751 True False False xxxx False
# a 760 True False False x True
# way 762 True False False xxx False
# which 766 True False False xxxx True
# had 772 True False False xxx True
# not 776 True False False xxx True
# happened 780 True False False xxxx False
# before 789 True False False xxxx True

# %% [markdown]
# #### 3- Part of Speech Tagging or POS Tagging :

# %%
# Here, two attributes of the Token class are accessed:
# 1- tag_ lists : the fine-grained part of speech.
# 2- pos_ lists : the coarse-grained part of speech.

# EN :

for token in token_EN:
    print (token, token.tag_, token.pos_, spacy.explain(token.tag_))

#AR :

for token in token_AR:
    print (token, token.tag_, token.pos_, spacy.explain(token.tag_))
# Out:
# perhaps RB ADV adverb
# one CD NUM cardinal number
# of IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# most RBS ADV adverb, superlative
# significant JJ ADJ adjective (English), other noun-modifier (Chinese)
# advances NNS NOUN noun, plural
# made VBN VERB verb, past participle
# by IN ADP conjunction, subordinating or preposition
# arabic JJ ADJ adjective (English), other noun-modifier (Chinese)
# mathematics NNS NOUN noun, plural
# began VBD VERB verb, past tense
# at IN ADP conjunction, subordinating or preposition
# this DT DET determiner
# time NN NOUN noun, singular or mass
# with IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# work NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# alkhwarizmi NN NOUN noun, singular or mass
# namely RB ADV adverb
# the DT DET determiner
# beginnings NNS NOUN noun, plural
# of IN ADP conjunction, subordinating or preposition
# algebra NNS NOUN noun, plural
# it PRP PRON pronoun, personal
# is VBZ AUX verb, 3rd person singular present
# important JJ ADJ adjective (English), other noun-modifier (Chinese)
# to TO PART infinitival "to"
# understand VB VERB verb, base form
# just RB ADV adverb
# how WRB ADV wh-adverb
# significant JJ ADJ adjective (English), other noun-modifier (Chinese)
# this DT DET determiner
# new JJ ADJ adjective (English), other noun-modifier (Chinese)
# idea NN NOUN noun, singular or mass
# was VBD AUX verb, past tense
# it PRP PRON pronoun, personal
# was VBD AUX verb, past tense
# a DT DET determiner
# revolutionary JJ ADJ adjective (English), other noun-modifier (Chinese)
# move NN NOUN noun, singular or mass
# away RB ADV adverb
# from IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# greek NNP PROPN noun, proper singular
# concept NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# mathematics NNS NOUN noun, plural
# which WDT DET wh-determiner
# was VBD VERB verb, past tense
# essentially RB ADV adverb
# geometry NN NOUN noun, singular or mass
# algebra NNS NOUN noun, plural
# was VBD VERB verb, past tense
# a DT DET determiner
# unifying JJ ADJ adjective (English), other noun-modifier (Chinese)
# theory NN NOUN noun, singular or mass
# which WDT DET wh-determiner
# allowedrational JJ ADJ adjective (English), other noun-modifier (Chinese)
# numbersirrational JJ ADJ adjective (English), other noun-modifier (Chinese)
# numbers NNS NOUN noun, plural
# geometrical JJ ADJ adjective (English), other noun-modifier (Chinese)
# magnitudes NNS NOUN noun, plural
# etc FW X foreign word
# to IN AUX conjunction, subordinating or preposition
# all DT DET determiner
# be VB AUX verb, base form
# treated VBN VERB verb, past participle
# as IN ADP conjunction, subordinating or preposition
# algebraic JJ ADJ adjective (English), other noun-modifier (Chinese)
# objects NNS NOUN noun, plural
# it PRP PRON pronoun, personal
# gave VBD VERB verb, past tense
# mathematics NNS NOUN noun, plural
# a DT DET determiner
# whole JJ ADJ adjective (English), other noun-modifier (Chinese)
# new JJ ADJ adjective (English), other noun-modifier (Chinese)
# development NN NOUN noun, singular or mass
# path NN NOUN noun, singular or mass
# so RB ADV adverb
# much RB ADV adverb
# broader JJR ADJ adjective, comparative
# in IN ADP conjunction, subordinating or preposition
# concept NN NOUN noun, singular or mass
# to IN ADP conjunction, subordinating or preposition
# that DT DET determiner
# which WDT DET wh-determiner
# had VBD AUX verb, past tense
# existed VBN VERB verb, past participle
# before RB ADV adverb
# and CC CCONJ conjunction, coordinating
# provided VBD VERB verb, past tense
# a DT DET determiner
# vehicle NN NOUN noun, singular or mass
# for IN ADP conjunction, subordinating or preposition
# future JJ ADJ adjective (English), other noun-modifier (Chinese)
# development NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# subject NN NOUN noun, singular or mass
# another DT DET determiner
# important JJ ADJ adjective (English), other noun-modifier (Chinese)
# aspect NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# introduction NN NOUN noun, singular or mass
# of IN ADP conjunction, subordinating or preposition
# algebraic JJ ADJ adjective (English), other noun-modifier (Chinese)
# ideas NNS NOUN noun, plural
# was VBD VERB verb, past tense
# that IN SCONJ conjunction, subordinating or preposition
# it PRP PRON pronoun, personal
# allowed VBD VERB verb, past tense
# mathematics NNS NOUN noun, plural
# to TO PART infinitival "to"
# be VB AUX verb, base form
# applied VBN VERB verb, past participle
# to TO PART infinitival "to"
# itselfin VB VERB verb, base form
# a DT DET determiner
# way NN NOUN noun, singular or mass
# which WDT DET wh-determiner
# had VBD AUX verb, past tense
# not RB PART adverb
# happened VBN VERB verb, past participle
# before IN ADP conjunction, subordinating or preposition
# ربما NNP PROPN noun, proper singular
# كانت NNP PROPN noun, proper singular
# أحد NNP PROPN noun, proper singular
# أهم NNP PROPN noun, proper singular
# التطورات VBD VERB verb, past tense
# التي NNP PROPN noun, proper singular
# قامت VBD VERB verb, past tense
# بها NN NOUN noun, singular or mass
# الرياضيات JJ ADJ adjective (English), other noun-modifier (Chinese)
# العربية NN NOUN noun, singular or mass
# التي NNS NOUN noun, plural
# بدأت VBP VERB verb, non-3rd person singular present
# في IN ADP conjunction, subordinating or preposition
# هذا JJ ADJ adjective (English), other noun-modifier (Chinese)
# الوقت NNP PROPN noun, proper singular
# بعمل NNP PROPN noun, proper singular
# الخوارزمي NNP PROPN noun, proper singular
# وهي NNP PROPN noun, proper singular
# بدايات NNP PROPN noun, proper singular
# الجبر NNP PROPN noun, proper singular
# ومن NNP PROPN noun, proper singular
# المهم NN NOUN noun, singular or mass
# فهم NNP PROPN noun, proper singular
# كيف NNP PROPN noun, proper singular
# كانت NNP PROPN noun, proper singular
# هذه NNP PROPN noun, proper singular
# الفكرة NNP PROPN noun, proper singular
# الجديدة NNP PROPN noun, proper singular
# مهمة NNP PROPN noun, proper singular
# فقد NNP PROPN noun, proper singular
# كانت NNP PROPN noun, proper singular
# خطوة NNP PROPN noun, proper singular
# نورية VB VERB verb, base form
# بعيدا NNS NOUN noun, plural
# عن NNP PROPN noun, proper singular
# المفهوم NNP PROPN noun, proper singular
# اليوناني NNP PROPN noun, proper singular
# للرياضيات NNP PROPN noun, proper singular
# التي NNP PROPN noun, proper singular
# هي UH INTJ interjection
# في UH INTJ interjection
# جوهرها NNP PROPN noun, proper singular
# هندسة NNP PROPN noun, proper singular
# الجبر NNP PROPN noun, proper singular
# کان NNP PROPN noun, proper singular
# نظرية NNP PROPN noun, proper singular
# موحدة NNP PROPN noun, proper singular
# تتيح NNP PROPN noun, proper singular
# الأعداد NNP PROPN noun, proper singular
# الكسرية NN NOUN noun, singular or mass
# والأعداد NN NOUN noun, singular or mass
# اللا NNS NOUN noun, plural
# كسرية VBP VERB verb, non-3rd person singular present
# والمقادير NNP PROPN noun, proper singular
# الهندسية NNP PROPN noun, proper singular
# وغيرها NNP PROPN noun, proper singular
# أن NNP PROPN noun, proper singular
# تتعامل VB VERB verb, base form
# على NNP PROPN noun, proper singular
# أنها NNPS PROPN noun, proper plural
# أجسام NNP PROPN noun, proper singular
# جبرية NNP PROPN noun, proper singular
# وأعطت NNP PROPN noun, proper singular
# الرياضيات NNP PROPN noun, proper singular
# ككل NNP PROPN noun, proper singular
# مسارا NN NOUN noun, singular or mass
# جديدا NNS NOUN noun, plural
# للتطور VBP VERB verb, non-3rd person singular present
# بمفهوم NN NOUN noun, singular or mass
# أوسع NN NOUN noun, singular or mass
# بكثير NNP PROPN noun, proper singular
# من NNP PROPN noun, proper singular
# الذي NNP PROPN noun, proper singular
# كان NNP PROPN noun, proper singular
# موجودا NNP PROPN noun, proper singular
# من NN NOUN noun, singular or mass
# قبل NN NOUN noun, singular or mass
# وقم NNP PROPN noun, proper singular
# وسيلة VBP VERB verb, non-3rd person singular present
# للتنمية JJ ADJ adjective (English), other noun-modifier (Chinese)
# في IN ADP conjunction, subordinating or preposition
# هذا NNP PROPN noun, proper singular
# الموضوع NNP PROPN noun, proper singular
# مستقبلا NNP PROPN noun, proper singular
# وجانب NNP PROPN noun, proper singular
# آخر VBD VERB verb, past tense
# مهم NN NOUN noun, singular or mass
# لإدخال NN NOUN noun, singular or mass
# أفكار NNS NOUN noun, plural
# الجبر VBD VERB verb, past tense
# وهو NNP PROPN noun, proper singular
# أنه NNP PROPN noun, proper singular
# سمح NNP PROPN noun, proper singular
# بتطبيق NNP PROPN noun, proper singular
# الرياضيات NNP PROPN noun, proper singular
# على NNP PROPN noun, proper singular
# نفسها NNP PROPN noun, proper singular
# بطريقة NNP PROPN noun, proper singular
# لم NNP PROPN noun, proper singular
# تحدث NNP PROPN noun, proper singular
# من DT DET determiner
# قبل NN NOUN noun, singular or mass

# %% [markdown]
# #### 4- Chunking

# %%
# EN :

for chunk in token_EN.noun_chunks:
    print(chunk)

# AR : 

for chunk in token_AR.noun_chunks:
    print(chunk)
# Out:
# the most significant advances
# arabic mathematics
# this time
# the work
# alkhwarizmi
# namely the beginnings
# algebra
# it
# this new idea
# it
# a revolutionary move
# the greek concept
# mathematics
# geometry algebra
# a unifying theory
# allowedrational numbersirrational numbers
# algebraic objects
# it
# mathematics
# a whole new development path
# concept
# a vehicle
# future development
# the subject
# another important aspect
# the introduction
# algebraic ideas
# it
# mathematics
# a way
# ربما
# التي قامت بها الرياضيات العربية التي
# هذا الوقت بعمل الخوارزمي
# وهي بدايات الجبر ومن المهم فهم كيف كانت هذه الفكرة الجديدة مهمة فقد كانت خطوة
# بعيدا
# اللا
# والمقادير الهندسية وغيرها
# على أنها أجسام جبرية وأعطت الرياضيات ككل مسارا جديدا
# بمفهوم
# أوسع بكثير من الذي كان موجودا
# من قبل وقم
# مهم لإدخال أفكار
# وهو أنه سمح بتطبيق الرياضيات
# على نفسها بطريقة

# %% [markdown]
# #### 5- Lemmatization :

# %%
# EN :

for token in token_EN:
    print (token, token.lemma_)

# AR : 

for token in token_AR:
    print (token, token.lemma_)
# Out:
# perhaps perhaps
# one one
# of of
# the the
# most most
# significant significant
# advances advance
# made make
# by by
# arabic arabic
# mathematics mathematic
# began begin
# at at
# this this
# time time
# with with
# the the
# work work
# of of
# alkhwarizmi alkhwarizmi
# namely namely
# the the
# beginnings beginning
# of of
# algebra algebra
# it it
# is be
# important important
# to to
# understand understand
# just just
# how how
# significant significant
# this this
# new new
# idea idea
# was be
# it it
# was be
# a a
# revolutionary revolutionary
# move move
# away away
# from from
# the the
# greek greek
# concept concept
# of of
# mathematics mathematic
# which which
# was be
# essentially essentially
# geometry geometry
# algebra algebra
# was be
# a a
# unifying unifying
# theory theory
# which which
# allowedrational allowedrational
# numbersirrational numbersirrational
# numbers number
# geometrical geometrical
# magnitudes magnitude
# etc etc
# to to
# all all
# be be
# treated treat
# as as
# algebraic algebraic
# objects object
# it it
# gave give
# mathematics mathematic
# a a
# whole whole
# new new
# development development
# path path
# so so
# much much
# broader broad
# in in
# concept concept
# to to
# that that
# which which
# had have
# existed exist
# before before
# and and
# provided provide
# a a
# vehicle vehicle
# for for
# future future
# development development
# of of
# the the
# subject subject
# another another
# important important
# aspect aspect
# of of
# the the
# introduction introduction
# of of
# algebraic algebraic
# ideas idea
# was be
# that that
# it it
# allowed allow
# mathematics mathematic
# to to
# be be
# applied apply
# to to
# itselfin itselfin
# a a
# way way
# which which
# had have
# not not
# happened happen
# before before
# ربما ربما
# كانت كانت
# أحد أحد
# أهم أهم
# التطورات التطورات
# التي التي
# قامت قامت
# بها بها
# الرياضيات الرياضيات
# العربية العربية
# التي التي
# بدأت بدأت
# في في
# هذا هذا
# الوقت الوقت
# بعمل بعمل
# الخوارزمي الخوارزمي
# وهي وهي
# بدايات بدايات
# الجبر الجبر
# ومن ومن
# المهم المهم
# فهم فهم
# كيف كيف
# كانت كانت
# هذه هذه
# الفكرة الفكرة
# الجديدة الجديدة
# مهمة مهمة
# فقد فقد
# كانت كانت
# خطوة خطوة
# نورية نورية
# بعيدا بعيدا
# عن عن
# المفهوم المفهوم
# اليوناني اليوناني
# للرياضيات للرياضيات
# التي التي
# هي هي
# في في
# جوهرها جوهرها
# هندسة هندسة
# الجبر الجبر
# کان کان
# نظرية نظرية
# موحدة موحدة
# تتيح تتيح
# الأعداد الأعداد
# الكسرية الكسرية
# والأعداد والأعداد
# اللا اللا
# كسرية كسرية
# والمقادير والمقادير
# الهندسية الهندسية
# وغيرها وغيرها
# أن أن
# تتعامل تتعامل
# على على
# أنها أنها
# أجسام أجسام
# جبرية جبرية
# وأعطت وأعطت
# الرياضيات الرياضيات
# ككل ككل
# مسارا مسارا
# جديدا جديدا
# للتطور للتطور
# بمفهوم بمفهوم
# أوسع أوسع
# بكثير بكثير
# من من
# الذي الذي
# كان كان
# موجودا موجودا
# من من
# قبل قبل
# وقم وقم
# وسيلة وسيلة
# للتنمية للتنمية
# في في
# هذا هذا
# الموضوع الموضوع
# مستقبلا مستقبلا
# وجانب وجانب
# آخر آخر
# مهم مهم
# لإدخال لإدخال
# أفكار أفكار
# الجبر الجبر
# وهو وهو
# أنه أنه
# سمح سمح
# بتطبيق بتطبيق
# الرياضيات الرياضيات
# على على
# نفسها نفسها
# بطريقة بطريقة
# لم لم
# تحدث تحدث
# من من
# قبل قبل

# %% [markdown]
# #### 6- Parsing :

# %%
# EN : 

for token in token_EN:
    print (token.text, token.tag_, token.head.text, token.dep_)

# AR :

for token in token_AR:
    print (token.text, token.tag_, token.head.text, token.dep_)
# Out:
# perhaps RB one advmod
# one CD began nsubj
# of IN one prep
# the DT advances det
# most RBS significant advmod
# significant JJ advances amod
# advances NNS of pobj
# made VBN advances acl
# by IN made agent
# arabic JJ mathematics amod
# mathematics NNS by pobj
# began VBD began ROOT
# at IN began prep
# this DT time det
# time NN at pobj
# with IN began prep
# the DT work det
# work NN with pobj
# of IN work prep
# alkhwarizmi NN of pobj
# namely RB beginnings advmod
# the DT beginnings det
# beginnings NNS one appos
# of IN beginnings prep
# algebra NNS of pobj
# it PRP is nsubj
# is VBZ began ccomp
# important JJ is acomp
# to TO understand aux
# understand VB is xcomp
# just RB significant advmod
# how WRB significant advmod
# significant JJ was acomp
# this DT idea det
# new JJ idea amod
# idea NN was nsubj
# was VBD understand ccomp
# it PRP was nsubj
# was VBD understand ccomp
# a DT move det
# revolutionary JJ move amod
# move NN was attr
# away RB move advmod
# from IN away prep
# the DT concept det
# greek NNP concept amod
# concept NN from pobj
# of IN concept prep
# mathematics NNS of pobj
# which WDT was nsubj
# was VBD concept relcl
# essentially RB was advmod
# geometry NN algebra compound
# algebra NNS was attr
# was VBD began conj
# a DT theory det
# unifying JJ theory amod
# theory NN was attr
# which WDT magnitudes nsubj
# allowedrational JJ numbers amod
# numbersirrational JJ numbers amod
# numbers NNS geometrical nsubj
# geometrical JJ magnitudes amod
# magnitudes NNS treated nsubjpass
# etc FW magnitudes prep
# to IN treated aux
# all DT treated advmod
# be VB treated auxpass
# treated VBN treated ROOT
# as IN treated prep
# algebraic JJ objects amod
# objects NNS as pobj
# it PRP gave nsubj
# gave VBD objects relcl
# mathematics NNS gave dative
# a DT path det
# whole JJ path amod
# new JJ path amod
# development NN path compound
# path NN gave dobj
# so RB much advmod
# much RB broader advmod
# broader JJR treated advmod
# in IN broader prep
# concept NN in pobj
# to IN concept prep
# that DT to pobj
# which WDT existed nsubj
# had VBD existed aux
# existed VBN that relcl
# before RB existed advmod
# and CC existed cc
# provided VBD existed conj
# a DT vehicle det
# vehicle NN provided dobj
# for IN vehicle prep
# future JJ development amod
# development NN for pobj
# of IN development prep
# the DT subject det
# subject NN of pobj
# another DT aspect det
# important JJ aspect amod
# aspect NN provided dobj
# of IN aspect prep
# the DT introduction det
# introduction NN of pobj
# of IN introduction prep
# algebraic JJ ideas amod
# ideas NNS of pobj
# was VBD treated conj
# that IN allowed mark
# it PRP allowed nsubj
# allowed VBD was ccomp
# mathematics NNS applied nsubjpass
# to TO applied aux
# be VB applied auxpass
# applied VBN allowed ccomp
# to TO itselfin aux
# itselfin VB applied advcl
# a DT way det
# way NN itselfin dobj
# which WDT happened nsubj
# had VBD happened aux
# not RB happened neg
# happened VBN way relcl
# before IN happened prep
# ربما NNP بدأت nsubj
# كانت NNP التطورات compound
# أحد NNP التطورات compound
# أهم NNP التطورات compound
# التطورات VBD ربما nmod
# التي NNP التي amod
# قامت VBD التي amod
# بها NN الرياضيات npadvmod
# الرياضيات JJ العربية amod
# العربية NN التي compound
# التي NNS بدأت nsubj
# بدأت VBP بدأت ROOT
# في IN بدأت prep
# هذا JJ الوقت compound
# الوقت NNP الخوارزمي compound
# بعمل NNP الخوارزمي compound
# الخوارزمي NNP في pobj
# وهي NNP ومن nmod
# بدايات NNP ومن nmod
# الجبر NNP ومن compound
# ومن NNP المهم compound
# المهم NN فهم compound
# فهم NNP كيف compound
# كيف NNP خطوة compound
# كانت NNP خطوة compound
# هذه NNP خطوة compound
# الفكرة NNP الجديدة compound
# الجديدة NNP خطوة compound
# مهمة NNP خطوة compound
# فقد NNP خطوة compound
# كانت NNP خطوة compound
# خطوة NNP نورية nsubj
# نورية VB الخوارزمي relcl
# بعيدا NNS نورية dobj
# عن NNP اليوناني compound
# المفهوم NNP اليوناني compound
# اليوناني NNP بدأت npadvmod
# للرياضيات NNP التي compound
# التي NNP بدأت npadvmod
# هي UH كسرية intj
# في UH كسرية intj
# جوهرها NNP کان compound
# هندسة NNP الجبر compound
# الجبر NNP کان compound
# کان NNP والأعداد compound
# نظرية NNP والأعداد compound
# موحدة NNP والأعداد compound
# تتيح NNP والأعداد compound
# الأعداد NNP والأعداد compound
# الكسرية NN والأعداد compound
# والأعداد NN في nmod
# اللا NNS كسرية nsubj
# كسرية VBP كسرية ROOT
# والمقادير NNP الهندسية compound
# الهندسية NNP وغيرها compound
# وغيرها NNP كسرية dobj
# أن NNP تتعامل compound
# تتعامل VB كسرية conj
# على NNP أنها compound
# أنها NNPS جبرية compound
# أجسام NNP جبرية compound
# جبرية NNP جديدا compound
# وأعطت NNP جديدا compound
# الرياضيات NNP جديدا compound
# ككل NNP جديدا compound
# مسارا NN جديدا compound
# جديدا NNS للتطور nsubj
# للتطور VBP تتعامل ccomp
# بمفهوم NN للتطور dobj
# أوسع NN بكثير compound
# بكثير NNP موجودا nmod
# من NNP موجودا compound
# الذي NNP موجودا compound
# كان NNP موجودا compound
# موجودا NNP موجودا ROOT
# من NN وقم nmod
# قبل NN وقم compound
# وقم NNP وسيلة nsubj
# وسيلة VBP وجانب compound
# للتنمية JJ وسيلة dobj
# في IN وجانب det
# هذا NNP وجانب compound
# الموضوع NNP مستقبلا compound
# مستقبلا NNP وجانب compound
# وجانب NNP آخر nsubj
# آخر VBD آخر ROOT
# مهم NN لإدخال compound
# لإدخال NN أفكار compound
# أفكار NNS آخر dobj
# الجبر VBD آخر advcl
# وهو NNP سمح compound
# أنه NNP سمح compound
# سمح NNP الرياضيات npadvmod
# بتطبيق NNP الرياضيات compound
# الرياضيات NNP الرياضيات ROOT
# على NNP بطريقة compound
# نفسها NNP بطريقة compound
# بطريقة NNP الرياضيات dobj
# لم NNP تحدث compound
# تحدث NNP الرياضيات ccomp
# من DT الرياضيات prep
# قبل NN الرياضيات npadvmod

# %% [markdown]
# # Thank you for your attention
